# %%
# %sql
select*from CogsleyServices_SalesData
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-1374115040382321> in <module>
#       5     display(df)
#       6     return df
# ----> 7   _sqldf = ____databricks_percent_sql()
#       8 finally:
#       9   del ____databricks_percent_sql
#
# <command-1374115040382321> in ____databricks_percent_sql()
#       2   def ____databricks_percent_sql():
#       3     import base64
# ----> 4     df = spark.sql(base64.standard_b64decode("c2VsZWN0KmZyb20gQ29nc2xleVNlcnZpY2VzX1NhbGVzRGF0YQ==").decode())
#       5     display(df)
#       6     return df
#
# /databricks/spark/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     775         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     776         """
# --> 777         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     778
#     779     def table(self, tableName):
#
# ...

# %%
df=spark.sql("select*from CogsleyServices_SalesData")
display(df)
df.head(5)

# %%
display( 
    df
      .select("region")
      .distinct
      .orderBy("region")
      
        
        
   )

# %%
# %sql
select distinct region 
from CogsleyServices_SalesData
order by region

# %%
display(
    df
    .select(df["OrderID"],df["Rate"]*df["Quantity"])
    .groupBy("OrderID")
    .sum()
                        


)

# %%
# %sql
select OrderID, sum(Rate*Quantity)as OrderTotal
from CogsleyServices_SalesData
group by OrderID
